# %%
import pandas as pd 
import numpy as np 
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
data=pd.read_csv('Reviews.csv')
data = data[['ProductId','Summary','Text']].dropna()
data.head(2)
# Out:
#     ProductId                Summary  \
# 0  B001E4KFG0  Good Quality Dog Food
# 1  B00813GRG4      Not as Advertised
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...

# %%
sentiments=SentimentIntensityAnalyzer()

# %%
# data["positive"]=[sentiments.polarity_scores(i)["pos"] for i in data["Text"]]
# data["negative"]=[sentiments.polarity_scores(i)["neg"] for i in data["Text"]]
# data["neutral"]=[sentiments.polarity_scores(i)["neu"] for i in data["Text"]]
data["compound"]=[sentiments.polarity_scores(i)["compound"] for i in data["Text"]]

# %%
data.head(20)
# Out:
#      ProductId                                            Summary  \
# 0   B001E4KFG0                              Good Quality Dog Food
# 1   B00813GRG4                                  Not as Advertised
# 2   B000LQOCH0                              "Delight" says it all
# 3   B000UA0QIQ                                     Cough Medicine
# 4   B006K2ZZ7K                                        Great taffy
# 5   B006K2ZZ7K                                         Nice Taffy
# 6   B006K2ZZ7K      Great!  Just as good as the expensive brands!
# 7   B006K2ZZ7K                             Wonderful, tasty taffy
# 8   B000E7L2R4                                         Yay Barley
# 9   B00171APVA                                   Healthy Dog Food
# 10  B0001PB9FE                    The Best Hot Sauce in the World
# 11  B0009XLVG0  My cats LOVE this "diet" food better than thei...
# 12  B0009XLVG0               My Cats Are Not Fans of the New Food
# 13  B001GVISJM                                  fresh and greasy!
# 14  B001GVISJM                       Strawberry Twizzlers - Yummy
# 15  B001GVISJM           Lots of twizzlers, just what you expect.
# 16  B001GVISJM                                         poor taste
# 17  B001GVISJM                                           Love it!
# 18  B001GVISJM                                 GREAT SWEET CANDY!
# 19  B001GVISJM                            Home delivered twizlers
#
#                                                  Text  compound
# 0   I have bought several of the Vitality canned d...    0.9441
# 1   Product arrived labeled as Jumbo Salted Peanut...   -0.5664
# 2   This is a confection that has been around a fe...    0.8265
# 3   If you are looking for the secret ingredient i...    0.0000
# 4   Great taffy at a great price.  There was a wid...    0.9468
# 5   I got a wild hair for taffy and ordered this f...    0.8830
# 6   This saltwater taffy had great flavors and was...    0.9346
# 7   This taffy is so good.  It is very soft and ch...    0.9487
# 8   Right now I'm mostly just sprouting this so my...    0.6369
# 9   This is a very healthy dog food. Good for thei...    0.8313
# 10  I don't know if it's the cactus or the tequila...    0.9746
# 11  One of my boys needed to lose some weight and ...   -0.7579
# 12  My cats have been happily eating Felidae Plati...    0.2960
# 13  good flavor! these came securely packed... the...    0.9466
# 14  The Strawberry Twizzlers are my guilty pleasur...    0.6486
# 15  My daughter loves twizzlers and this shipment ...    0.5719
# 16  I love eating them and they are good for watch...    0.7481
# 17  I am very satisfied with my Twizzler purchase....    0.8883
# 18  Twizzlers, Strawberry my childhood favorite ca...    0.8957
# 19  Candy was delivered very fast and was purchase...    0.6077

# %%
sum =0 
for i in range(len(data['compound'])):
    if (data['compound'][i] < 0):
        sum += data['compound'][i]
sum
# Out:
# -1208.8070000000007

# %%
sum =0 
for i in range(len(data['compound'])):
    if (data['compound'][i] > 0):
        sum += data['compound'][i]
sum
# Out:
# 15518.240899999975
