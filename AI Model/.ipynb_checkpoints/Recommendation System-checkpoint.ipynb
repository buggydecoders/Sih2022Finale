# %%
import numpy as np
import pandas as pd
import ast
import pymongo
from pymongo import MongoClient
import json
import nltk
# nltk.download('wordnet')
# nltk.download('omw-1.4')
# nltk.download('stopwords')
# nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from bson import ObjectId
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Database Connection

# %%
CONNECTION_STRING = "mongodb://prathamrasal:pratham@movies-shard-00-00.3vhge.mongodb.net:27017,movies-shard-00-01.3vhge.mongodb.net:27017,movies-shard-00-02.3vhge.mongodb.net:27017/sihdb?ssl=true&replicaSet=atlas-13vdfc-shard-0&authSource=admin&retryWrites=true&w=majority"
client = MongoClient(CONNECTION_STRING)
db = client['sihdb']
resources = db['resources']
institutes =db['institutes']

# %%
resInfo=resources.find()
resInfo= list(resInfo)
resDF = pd.DataFrame(resInfo)
# title, description, cost , reputation point
# resDF.head(2)

# %%
insInfo=institutes.find()
insInfo= list(insInfo)
insDF = pd.DataFrame(insInfo)
insDF.head(3)
for i in range(len(insDF)):
#     print(insDF.iloc[i].address['street'])
    insDF['street'] = insDF.iloc[i].address['street']
    insDF['city'] = insDF.iloc[i].address['city']
    insDF['state'] = insDF.iloc[i].address['state']
insDF = insDF[['_id','instituteName','aisheCode','naac','street','city','state']]
insDF.head(2)
# Out:
#                         _id                              instituteName  \
# 0  62f412416fc0348badda5ab7       CHAUDHARY DEVI LAL UNIVERSITY, SIRSA
# 1  62f412416fc0348badda5ab9  MODY UNIVERSITY OF SCIENCE AND TECHNOLOGY
#
#   aisheCode naac                                             street  \
# 0    U-0160    B   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...
# 1    U-0412   A+   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...
#
#         city             state
# 0   Rajgarh   Himachal pradesh
# 1   Rajgarh   Himachal pradesh

# %%
##TESTING 

insDF.rename(columns = {'_id':'insId'}, inplace = True)
resDF.rename(columns = {'lendingInstitute':'insId'}, inplace = True)

resDF = resDF.merge(insDF,on='insId')
resDF.tail(20)
# Out:
#                            _id  \
# 2717  62f415844d4f5fe937b409b1
# 2718  62f415864d4f5fe937b40a09
# 2719  62f415884d4f5fe937b40a79
# 2720  62f415994d4f5fe937b40e19
# 2721  62f4159a4d4f5fe937b40e55
# 2722  62f4159d4d4f5fe937b40ef1
# 2723  62f415a74d4f5fe937b410af
# 2724  62f415884d4f5fe937b40a69
# 2725  62f4158c4d4f5fe937b40b2f
# 2726  62f4158e4d4f5fe937b40bcf
# 2727  62f415924d4f5fe937b40cb7
# 2728  62f415944d4f5fe937b40d0f
# 2729  62f415964d4f5fe937b40d99
# 2730  62f415974d4f5fe937b40dc7
# 2731  62f415984d4f5fe937b40dd7
# 2732  62f415a04d4f5fe937b40f65
# 2733  62f415a04d4f5fe937b40f6b
# 2734  62f415a64d4f5fe937b4109f
# 2735  62f415ad4d4f5fe937b411ed
# 2736  62f415b84d4f5fe937b4144d
#
#                                                   title   cost  \
# 2717                                     Niremo Loafers    999
# 2718         D'clair Micromax Bolt Q324 Battery Charger    600
# 2719          Candy House Solid Men's Polo Neck T-Shirt   2499
# 2720  Radiant Bay Priceless Bond White Gold Diamond ...  25730
# 2721             Fuson Back Cover for Samsung Galaxy J7   1299
# 2722       Amber Animal Print Women's Wrap Around Skirt   1100
# 2723        Madaam Sports Bra Women's Full Coverage Bra    999
# 2724       Speedwav 240363 Sun Shade For Renault Duster   1400
# 2725          Candy House Solid Men's Polo Neck T-Shirt   2999
# 2726                  Craft Trade Oval Wood Coaster Set    790
# 2727               Cross Fingers Hero Two Wheeler Cover    990
# 2728         Life by Shoppers Stop Premium Men's Cargos   1799
# 2729             Fuson Back Cover for Samsung Galaxy J7   1299
# 2730         Handecor Ballet Dancer Showpiece  -  30 cm   3299
# 2731          Kasemantra Back Cover for Apple iPad Mini   1499
# 2732                                  Metro Women Flats   1590
# 2733                      Clarks Olga Masie Women Flats   2799
# 2734                      Khadi Lip Balm Pack of 2 Lime    140
# 2735              Younky Blue Women's Full Coverage Bra    399
# 2736              Vivity Comfortable Women's Plunge Bra   1200
#
#                                             description  \
# 2717  Specifications of Niremo Loafers General Occas...
# 2718  Key Features of D'clair Micromax Bolt Q324 Bat...
# 2719  Key Features of Candy House Solid Men's Polo N...
# 2720  Radiant Bay Priceless Bond White Gold Diamond ...
# 2721  Fuson Back Cover for Samsung Galaxy J7 (Multic...
# 2722  Amber Animal Print Women's Wrap Around Skirt -...
# 2723  Madaam Sports Bra Women's Full Coverage Bra - ...
# 2724  Specifications of Speedwav 240363 Sun Shade Fo...
# 2725  Key Features of Candy House Solid Men's Polo N...
# 2726  Key Features of Craft Trade Oval Wood Coaster ...
# 2727  Key Features of Cross Fingers Hero Two Wheeler...
# 2728  Life by Shoppers Stop Premium Men's Cargos - B...
# 2729  Fuson Back Cover for Samsung Galaxy J7 (Multic...
# 2730  Buy Handecor Ballet Dancer Showpiece  -  30 cm...
# 2731  Kasemantra Back Cover for Apple iPad Mini (Bro...
# 2732  Flipkart.com: Buy Metro Women Flats only for R...
# 2733  Clarks Olga Masie Women Flats\n               ...
# 2734  Key Features of Khadi Lip Balm Pack of 2 Lime ...
# 2735  Younky Blue Women's Full Coverage Bra - Buy Bl...
# 2736  Vivity Comfortable Women's Plunge Bra - Buy Bl...
#
#                                                feedback  \
# 2717  [{"rating":1,"from":[{"$oid":"6234cd1222ace6f8...
# 2718  [{"rating":2,"from":[{"$oid":"6234cce722ace6f8...
# 2719  [{"rating":2,"from":[{"$oid":"6234cd0022ace6f8...
# 2720  [{"rating":4,"from":[{"$oid":"6234ccdd22ace6f8...
# 2721  [{"rating":1,"from":[{"$oid":"6234ccdd22ace6f8...
# 2722  [{"rating":0,"from":[{"$oid":"6234cce822ace6f8...
# 2723  [{"rating":4,"from":[{"$oid":"6234cd0922ace6f8...
# 2724  [{"rating":3,"from":[{"$oid":"6234ccf122ace6f8...
# 2725  [{"rating":2,"from":[{"$oid":"6234ccf222ace6f8...
# 2726  [{"rating":1,"from":[{"$oid":"6234ccea22ace6f8...
# 2727  [{"rating":4,"from":[{"$oid":"6234cd0922ace6f8...
# 2728  [{"rating":3,"from":[{"$oid":"6234ccfd22ace6f8...
# 2729  [{"rating":2,"from":[{"$oid":"6234cce622ace6f8...
# 2730  [{"rating":4,"from":[{"$oid":"6234cd0922ace6f8...
# 2731  [{"rating":4,"from":[{"$oid":"6234cd0922ace6f8...
# 2732  [{"rating":4,"from":[{"$oid":"6234cd0e22ace6f8...
# 2733  [{"rating":2,"from":[{"$oid":"6234cd0122ace6f8...
# 2734  [{"rating":4,"from":[{"$oid":"6234cce422ace6f8...
# 2735  [{"rating":4,"from":[{"$oid":"6234cd1222ace6f8...
# 2736  [{"rating":3,"from":[{"$oid":"6234cce922ace6f8...
#
#                          insId  __v  \
# 2717  62f412426fc0348badda5ad1    0
# 2718  62f412426fc0348badda5ad1    0
# 2719  62f412426fc0348badda5ad1    0
# 2720  62f412426fc0348badda5ad1    0
# 2721  62f412426fc0348badda5ad1    0
# 2722  62f412426fc0348badda5ad1    0
# 2723  62f412426fc0348badda5ad1    0
# 2724  62f412426fc0348badda5abf    0
# 2725  62f412426fc0348badda5abf    0
# 2726  62f412426fc0348badda5abf    0
# 2727  62f412426fc0348badda5abf    0
# 2728  62f412426fc0348badda5abf    0
# 2729  62f412426fc0348badda5abf    0
# 2730  62f412426fc0348badda5abf    0
# 2731  62f412426fc0348badda5abf    0
# 2732  62f412426fc0348badda5abf    0
# 2733  62f412426fc0348badda5abf    0
# 2734  62f412426fc0348badda5abf    0
# 2735  62f412426fc0348badda5abf    0
# 2736  62f412426fc0348badda5abf    0
#
#                                           instituteName aisheCode naac  \
# 2717  MANIPAL ACADEMY OF HIGHER EDUCATION (DEEMED-TO...    U-0234  A++
# 2718  MANIPAL ACADEMY OF HIGHER EDUCATION (DEEMED-TO...    U-0234  A++
# 2719  MANIPAL ACADEMY OF HIGHER EDUCATION (DEEMED-TO...    U-0234  A++
# 2720  MANIPAL ACADEMY OF HIGHER EDUCATION (DEEMED-TO...    U-0234  A++
# 2721  MANIPAL ACADEMY OF HIGHER EDUCATION (DEEMED-TO...    U-0234  A++
# 2722  MANIPAL ACADEMY OF HIGHER EDUCATION (DEEMED-TO...    U-0234  A++
# 2723  MANIPAL ACADEMY OF HIGHER EDUCATION (DEEMED-TO...    U-0234  A++
# 2724  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2725  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2726  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2727  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2728  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2729  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2730  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2731  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2732  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2733  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2734  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2735  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
# 2736  SHAHEED MAHENDRA KARMA VISHWAVIDYALAYA, BASTAR...    U-0082    C
#
#                                                  street       city  \
# 2717   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2718   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2719   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2720   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2721   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2722   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2723   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2724   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2725   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2726   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2727   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2728   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2729   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2730   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2731   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2732   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2733   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2734   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2735   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
# 2736   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...   Rajgarh
#
#                  state
# 2717  Himachal pradesh
# 2718  Himachal pradesh
# 2719  Himachal pradesh
# 2720  Himachal pradesh
# 2721  Himachal pradesh
# 2722  Himachal pradesh
# 2723  Himachal pradesh
# 2724  Himachal pradesh
# 2725  Himachal pradesh
# 2726  Himachal pradesh
# 2727  Himachal pradesh
# 2728  Himachal pradesh
# 2729  Himachal pradesh
# 2730  Himachal pradesh
# 2731  Himachal pradesh
# 2732  Himachal pradesh
# 2733  Himachal pradesh
# 2734  Himachal pradesh
# 2735  Himachal pradesh
# 2736  Himachal pradesh

# %% [markdown]
# # Data Selection

# %%
# # resDF = resDF[['_id','title','description','cost','lendingInstitute']]
# temp = []
# for i in range(len(resDF)):
#     ins = institutes.find_one({'_id':resDF['lendingInstitute'][i]})
#     temp.append(ins)
# resDF['city'] = ''
# resDF['street'] = ''
# resDF['state'] = ''
# resDF['naac'] = ''
# resDF['reputationPoint'] = ''

# for i in range(len(temp)):
#     resDF['street'][i] = temp[i]['address']['street']
#     resDF['city'][i] = temp[i]['address']['city']
#     resDF['state'][i] = temp[i]['address']['state']
#     resDF['naac'][i] = temp[i]['naac']
#     resDF['reputationPoint'][i] = temp[i]['reputationPoint']

# %%
resDF = resDF[['title','description','cost','city','street','state','naac']]
resDF.head(5)
# Out:
#                                          title  \
# 0       Babeezworld Dungaree Baby Boy's  Combo
# 1  Shilpi Casual Cape Sleeve Solid Women's Top
# 2                Navaksha Necktie Men's  Combo
# 3        Autofurnish Car Cover For Santro Xing
# 4   Speedwav 240428 Sun Shade For Maruti Swift
#
#                                          description  cost       city  \
# 0  Specifications of Babeezworld Dungaree Baby Bo...   999   Rajgarh
# 1  Shilpi Casual Cape Sleeve Solid Women's Top - ...   499   Rajgarh
# 2  Navaksha Necktie Men's  Combo\n               ...  1550   Rajgarh
# 3  Specifications of Autofurnish Car Cover For Sa...  1530   Rajgarh
# 4  Specifications of Speedwav 240428 Sun Shade Fo...  1400   Rajgarh
#
#                                               street             state naac
# 0   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...  Himachal pradesh    A
# 1   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...  Himachal pradesh    A
# 2   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...  Himachal pradesh    A
# 3   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...  Himachal pradesh    A
# 4   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...  Himachal pradesh    A

# %%
resDF.dropna(inplace=True)
resDF.isnull().sum()
# Out:
# title          0
# description    0
# cost           0
# city           0
# street         0
# state          0
# naac           0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
lematizer = WordNetLemmatizer()
def getCleanText(text):
    text = str(text)
    words = word_tokenize(text)
    wordd = []
    for w in words:
        word = lematizer.lemmatize(w)
        if not word in set(stopwords.words('english')):
            wordd.append(word)
    cleanText = ' '.join(wordd)
    return cleanText

def toLowerCase(text):
    text = str(text)
    return text.lower()

# %%
resDF['description'] = resDF['description'].apply(getCleanText)

# %% [markdown]
# # Data Processing

# %%
resDF['tags'] = ''
resDF.head(2)
# Out:
#                                          title  \
# 0       Babeezworld Dungaree Baby Boy's  Combo
# 1  Shilpi Casual Cape Sleeve Solid Women's Top
#
#                                          description cost       city  \
# 0  Specifications Babeezworld Dungaree Baby Boy '...  999   Rajgarh
# 1  Shilpi Casual Cape Sleeve Solid Women 's Top -...  499   Rajgarh
#
#                                               street             state naac  \
# 0   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...  Himachal pradesh    A
# 1   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...  Himachal pradesh    A
#
#   tags
# 0
# 1

# %%
def generateTag():
    resDF['tags'] = resDF['title'] + " " + resDF['description']+ " "  + resDF['cost']+ " " + resDF['city']+ " " +resDF['street']+ " " +resDF['state']+ " " +resDF['naac']
    resDF['tags'] = resDF['tags'].apply(lambda x: x.lower())
# resDF['tags'].head(2)
generateTag()

# %% [markdown]
# # Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(resDF['tags'].values.astype('str')).toarray()

# %%
# cv.get_feature_names()

# %%
similarity = cosine_similarity(vector)

# %%
# sorted(list(enumerate(similarity[0])),reverse=True,key= lambda x:x[1])

# %%
def vectorize():
    pass

# %%
def recommend(title):
    title_index =  resDF[resDF['title'] ==title].index[0]
    distance = similarity[title_index]
    recommended_list = sorted(list(enumerate(distance)),reverse=True,key= lambda x:x[1])
    for i in recommended_list[1:6]:
        print(resDF.iloc[i[0]].title)
        
def getInstitute(instituteId):
    instituteId =  ObjectId(instituteId)
    institute = institutes.find_one({"_id": instituteId})
    institute = pd.DataFrame(institute)=
    city = institute['address']['city']
    street = institute['address']['street']
    state = institute['address']['state']
    naac = institute['naac'][0]
    tags = city + street +state + naac
    myDict = {
         "title":" ",
         "description":" ", 
         "cost":" ", 
         "city": city,
         "street":street,
         "state":state,
         "naac": naac,
         "tags": tags.lower()
    }
    newDF = resDF.append(myDict,ignore_index = True)
    return newDF

newDF = getInstitute('62f412426fc0348badda5ac9')
generateTag()
newDF.tail(5)
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_16204\3924769155.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newDF = resDF.append(myDict,ignore_index = True)
#                                       title  \
# 2726          Clarks Olga Masie Women Flats
# 2727          Khadi Lip Balm Pack of 2 Lime
# 2728  Younky Blue Women's Full Coverage Bra
# 2729  Vivity Comfortable Women's Plunge Bra
# 2730
#
#                                             description  cost         city  \
# 2726  Clarks Olga Masie Women Flats Price : Rs . 1,6...  2799     Rajgarh
# 2727  Key Features Khadi Lip Balm Pack 2 Lime Natura...   140     Rajgarh
# 2728  Younky Blue Women 's Full Coverage Bra - Buy B...   399     Rajgarh
# 2729  Vivity Comfortable Women 's Plunge Bra - Buy B...  1200     Rajgarh
# 2730                                                            Gorakhpur
#
#                                                  street             state  \
# 2726   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...  Himachal pradesh
# 2727   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...  Himachal pradesh
# 2728   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...  Himachal pradesh
# 2729   173101 , VPO - Baru Sahib, Teh. - Pachhad, Vi...  Himachal pradesh
# 2730   273010 , Madan Mohan Malaviya University of T...     Uttar pradesh
#
#      naac                                               tags
# 2726    C  clarks olga masie women flats clarks olga masi...
# 2727    C  khadi lip balm pack of 2 lime key features kha...
# 2728    C  younky blue women's full coverage bra younky b...
# 2729    C  vivity comfortable women's plunge bra vivity c...
# 2730    A   gorakhpur  273010 , madan mohan malaviya univ...

# %%
# recommend("Kasemantra Back Cover for Apple iPad Mini")
